# %%
import requests
import json
import calendar
import time

def getMedicionesDateRange(url_api, params, fecha):
    
    # Se envía petición al servidor mediante la api con la url construida: 
    #    API_URL + Parámetros (fechaini y fechafin) + api_key (proporcionada por AEMET con validez de 3 meses)
    # Se debe hacer un bucle que solicite mediciones del periodo que deseemos con rangos no superioroes a 31 días. 
    # Lo ideal sería solicitar desde 01/01/2000 por meses hasta el mes en curso (Aún por implementar)
    resp_api = requests.request("GET", url_api, headers=headers, params=params)

    # Se toman los datos devueltos en la respuesta que se trata de un objeto de tipo str con formato json
    #print(type(resp_api.text))
    rjson =  resp_api.text
    print(rjson)

    # Decodificamos el objeto json:
    res = json.loads(rjson)

    # Obtenenmos como resultado un dictionary python:
    #print(type(res))
    #print(res["datos"])

    # Tomamos la URL de descarga del set de datos generado por el servidor en respuesta a nuestra petición
    url_data = res["datos"]

    # Se envía petición al servidor para descargar los datos
    resp = requests.request("GET", url_data, headers=headers)
    #print(type(resp.text))

    # Se toman los datos devueltos en la respuesta que se trata de un objeto de tipo str con formato json
    rjson2 =  resp.text

    # Decodificamos el objeto json, obteniendo un conjunto de mediciones en formato de Diccionario Python:
    mediciones = json.loads(rjson2)
    #print(type(mediciones))

    # A partir del diccionario obtenido, generaremos un archivo json donde guardaremos sólo los datos que necesitamos:
    #   fecha: fecha de medición ('AAAA-MM-DD')
    #   nombre: nombre (ubicación) de la estación
    #   provincia: Provincia de la estación
    #   tmed: Temperatura media de ese día en grados celsius
    #   prec: Precipitación diaria de 07 a 07 en mm (IP menos de 0.1 mm)

    # Inicializamos Diccionario vacio que contendrá los datos que deseamos guardar en formato json 
    datos = {}
    # Inicializamos lista vacia que contendrá mediciones
    datos["mediciones"] = []
    # Inicializamos Diccionario vacio que utilizaremos en el paso intermedio de recuperación de mediciones 
    medicion = {}

    # Recorremos el json que nos devolvió el servidor y vamos construyendo nuestro propio set con los datos que deseamos
    for item in mediciones:
        for clave, valor in item.items():
            if clave in ('fecha','nombre','provincia','tmed','prec'):
                medicion[clave] = valor
        datos["mediciones"].append(medicion.copy())

    #print(datos['mediciones'])

    # Volcamos los datos generados por nosotros en un nuevo fichero que se llamará mediciones.json
    with open('mediciones.json', 'a') as file:
        json.dump(datos, file, indent=4)

    print("Done")

# %%
main   = 'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/'
param1 = 'fechaini/'
param2 = 'fechafin/'
slash  = '/'
todas  = 'todasestaciones/'

años = list(range(2000,2021))
meses = list(range(1,13))
guion = '-'
finfecha = 'T00:00:00UTC'
finfecha2 = 'T23:59:59UTC'

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhcnVpenBsYUB1b2MuZWR1IiwianRpIjoiOWNjMzUyMmItZGNjYy00MzUwLTk3YWEtZjU0YWMyNTgzMmFiIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2MDI5NjU1NTEsInVzZXJJZCI6IjljYzM1MjJiLWRjY2MtNDM1MC05N2FhLWY1NGFjMjU4MzJhYiIsInJvbGUiOiIifQ.m9Dj6SN3DCLl-uIt1lFMbJMfY2DnmrfdFc2uX_d73i8"}

headers = {'cache-control': "no-cache"}

for año in años:
    t0 = time.time()
    
    for mes in meses:
        fecha = str(año) + guion + str(mes)
        fini = str(año) + guion + str(mes) + guion + '1' + finfecha
        ffin = str(año) + guion + str(mes) + guion + str(calendar.monthrange(año, mes)[1]) + finfecha2
        
        url_api = main + param1 + fini + slash + param2 + ffin + slash + todas
        #print(url_api)
        
        getMedicionesDateRange(url_api, querystring, fecha)
        
        #estimación del tiempo de respuesta en segundos
#         response_delay = time.time() - t0
        #espera de 10x, con respecto al tiempo de respuesta
#         time.sleep(2 * response_delay)
#         print(response_delay)
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/53514ed4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5ab86046",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f63c062b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cee45035",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/eb884a1f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6b5588b6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/02f04f49",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d35520bc",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3abc0936",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6c0c9460",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5d601ac7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d92abf54",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/180f2681",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/fc490735",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e6eba95a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3b67e16f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/40790bc0",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8fd886e2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/11e4f51d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2ec0ceac",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/40c1bb78",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/499b0300",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4b3ede13",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3e8f3601",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/44a8966b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c4a526bc",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/357fc432",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/bca26dfa",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8722cc31",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0cec8fb6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/30d912f4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2cf73685",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/9b88a0bf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/71e88e21",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8541a1f9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/bed9449b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/aa7e8cfc",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/95179693",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6b6be476",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/72ceed82",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a1c9cdcd",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f12a2b15",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/14fae332",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ac7a29c2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7994b6e9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/38e6da5b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/01597e88",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/841dd479",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/65980595",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d78097f0",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d3759f14",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6b721c0d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/564ec84d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/fd019ffa",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1c7f4045",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/53bd4a09",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3196f84d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/9494aa6d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/18e81180",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/440b9bb5",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c3b59c74",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c11e64a3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/29d70a6f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/18e9728b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e69f9e77",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0d10b4e1",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b52766f1",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0b96ed07",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4fb7405e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a754e475",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/57f4da01",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/731f4edf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/737f15cf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/26fe54a3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/29872efe",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ff937a1a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f00ed0d3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d6222543",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ba665f99",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5c94fb1a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e4b83ebf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b5cfd1d9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ecf9fc83",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a1837586",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b5976226",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/602e440f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a7ba4641",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/94be21b4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c2a3c9b3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a1129dd3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e6791250",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7b6aa783",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/33c1e1b8",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5e0f8955",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cc53dda2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/508d2a4d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e0ead4f9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/747801da",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6a6e0440",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d90ebc29",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/420b7fd9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/528ff62f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/426b5a9e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1db9a1fc",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7b209f00",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ec90aaf1",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/523c0370",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cd6933e8",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d5e19b87",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0ff8bfcc",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/959d0991",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8d67a4b7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/68f4b2ff",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8133a829",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e354bdbb",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5e45b954",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ded47afd",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/65c2ee59",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/33baf701",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a3d5d306",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b3290247",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d766e3e3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/261db125",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0ad23027",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1646adc9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cf73be78",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/912a191d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a08c83c9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/abfdb05d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e0904ece",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0ecefaa8",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ed1c33ab",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f2fee7f7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7dae5fe8",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/fc3f5cae",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8724d883",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e9b81cc9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6cb7ddc7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4836dc43",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/913193eb",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/008133e3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/55a14dae",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e92ef58b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f2e819ad",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/49260143",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f07f024a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/fb449199",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/dde4060a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c6796c5a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/01cd1166",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/252cb0c3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7c796577",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/dc82a08d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8c8373ab",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/72112c00",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7d40bcfd",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/27fa082c",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/29c71da2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/34b0879b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/883afaaf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e08c84a4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f0a6929d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2c95e0b6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f98cd0d2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/17c5fd15",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/65d09afa",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e34b94bb",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/23238434",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cf9da10a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/231f69bf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5cc1a846",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4df0eade",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c366ca7c",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/dfa06e05",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/74c77a7a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d503f6f3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3c8bd338",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/505bd5e1",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/77e217fe",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/89153d72",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/72f07aad",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a1877da3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2ea34afd",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/add4730e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7972687f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2e107eb1",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c7bb8efb",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c5586a54",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d786a041",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1fa17a1a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1ef15d47",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7264fb31",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/191a8f65",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/1848fb13",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/286c17f8",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8827d7d5",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6f76aa9c",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/9ae7cac5",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6b674516",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/992cf0c0",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/172d8e45",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7d555492",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6fc65467",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c73f15e6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d227d746",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8ea48297",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f080bb85",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/37212288",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d35d8847",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/30856a70",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/841444eb",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/563736be",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a6891a7b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/07d0600f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cd884df9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/993b610f",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d5dc1751",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3e9e9e80",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b689fa86",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/752d0f6e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/dcb0d5a4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/04155f00",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6a096e30",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/cb7c7454",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/338731e2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ec97aeee",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/97b0f4d5",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/0c3d7b26",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8c7f5584",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b3c5e497",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f106a1e4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a40637e7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a97ea83c",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/31a7a025",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8c12e257",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a38ab692",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d3c4bc5d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e44f2a59",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/95baa439",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5dbf8d9b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/251af6d9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/da8d3053",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/9876804e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5f5ad8c6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c23c8017",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/716d7737",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6d30cb46",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/978a02fd",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3b6a5608",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f6ad4752",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Done
# {
#   "descripcion" : "No hay datos que satisfagan esos criterios",
#   "estado" : 404
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-322806237003> in <module>
#      26         #print(url_api)
#      27
# ---> 28         getMedicionesDateRange(url_api, querystring, fecha)
#      29
#      30         #estimación del tiempo de respuesta en segundos
#
# <ipython-input-44-ab82adcc8511> in getMedicionesDateRange(url_api, params, fecha)
#      25
#      26     # Tomamos la URL de descarga del set de datos generado por el servidor en respuesta a nuestra petición
# ---> 27     url_data = res["datos"]
#      28
#      29     # Se envía petición al servidor para descargar los datos
#
# KeyError: 'datos'

# %%
import json

#  Test apertura fichero generado. Pruebo filtrado por localización y fecha. 
#  Se deberá ver como asociar una temperatura 
with open('datos.json') as file:
    datos = json.load(file)
    for medicion in datos['mediciones']:
        if medicion['fecha'] == '2020-10-11' and medicion['nombre'] == 'LLEIDA':
            print(medicion)

print("Done")
# Out:
# {'fecha': '2020-10-11', 'nombre': 'LLEIDA', 'provincia': 'LLEIDA', 'tmed': '15,0', 'prec': '0,0'}
# Done
