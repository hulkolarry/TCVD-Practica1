# %%
import pandas as pd

# %%
cols = ["EquipoAnf", "EquipoVis", "ResulAnf", "ResulVis", "Fecha","Estadio", "Ciudad", "Arbitro"]
dsFutbol = pd.read_csv("Partidos.csv", sep=',', header=None, names=cols)
dsFutbol
# Out:
#           EquipoAnf            EquipoVis  ResulAnf  ResulVis       Fecha  \
# 0             Elche        Real Sociedad         0         3  26/09/2020
# 1     Real Sociedad          Real Madrid         0         0  20/09/2020
# 2             Eibar              Osasuna         0         0  18/10/2020
# 3         Barcelona          Real Madrid         1         3  24/10/2020
# 4             Eibar        Athletic Club         1         2  27/09/2020
# ...             ...                  ...       ...       ...         ...
# 7668      Barcelona             Espanyol         4         2  10/12/2000
# 7669  Real Sociedad        Celta de Vigo         2         2  04/02/2001
# 7670       Numancia            Barcelona         1         1  18/03/2001
# 7671    Real Madrid  Racing de Santander         1         0  17/02/2001
# 7672    Real Madrid               Málaga         4         3  04/02/2001
#
#                             Estadio         Ciudad             Arbitro
# 0           Estadio Martínez Valero          Elche        Díaz de Mera
# 1                            Anoeta  San Sebastián    Martínez Munuera
# 2       Estadio Municipal de Ipurua            n/d       Medié Jiménez
# 3                          Camp Nou      Barcelona    Martínez Munuera
# 4       Estadio Municipal de Ipurua            n/d        Cordero Vega
# ...                             ...            ...                 ...
# 7668            Nou Camp (Nou Camp)      Barcelona       Daudén Ibáñez
# 7669                         Anoeta  San Sebastián  Andradas Asurmendi
# 7670  Los Pajaritos (Los Pajaritos)          Soria       Pérez Burrull
# 7671              Santiago Bernabéu         Madrid       Daudén Ibáñez
# 7672              Santiago Bernabéu         Madrid       Llonch Andreu
#
# [7673 rows x 8 columns]

# %%
dsFutbol['Ciudad'][dsFutbol['EquipoAnf'] == 'Eibar'] = 'Eibar'
dsFutbol.head()
# Out:
# <ipython-input-3-0c6e84da8524>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dsFutbol['Ciudad'][dsFutbol['EquipoAnf'] == 'Eibar'] = 'Eibar'
#        EquipoAnf      EquipoVis  ResulAnf  ResulVis       Fecha  \
# 0          Elche  Real Sociedad         0         3  26/09/2020
# 1  Real Sociedad    Real Madrid         0         0  20/09/2020
# 2          Eibar        Osasuna         0         0  18/10/2020
# 3      Barcelona    Real Madrid         1         3  24/10/2020
# 4          Eibar  Athletic Club         1         2  27/09/2020
#
#                        Estadio         Ciudad           Arbitro
# 0      Estadio Martínez Valero          Elche      Díaz de Mera
# 1                       Anoeta  San Sebastián  Martínez Munuera
# 2  Estadio Municipal de Ipurua          Eibar     Medié Jiménez
# 3                     Camp Nou      Barcelona  Martínez Munuera
# 4  Estadio Municipal de Ipurua          Eibar      Cordero Vega

# %%
dsFutbol[dsFutbol['Ciudad'] == 'n/d']
# Out:
#      EquipoAnf               EquipoVis  ResulAnf  ResulVis       Fecha  \
# 3881     Xerez      Atlético de Madrid         0         2  05/12/2009
# 3884     Xerez                  Málaga         1         1  04/10/2009
# 3910     Xerez                Zaragoza         3         2  08/05/2010
# 3924     Xerez     Racing de Santander         2         2  18/04/2010
# 3928     Xerez       Sporting de Gijón         0         0  22/11/2009
# 3930     Xerez  Deportivo de La Coruña         0         3  23/09/2009
# 3933     Xerez                 Almería         2         1  01/05/2010
# 3941     Xerez           Athletic Club         0         1  13/09/2009
# 3957     Xerez                 Sevilla         0         2  31/10/2009
# 3982     Xerez              Villarreal         2         1  18/10/2009
# 4007     Xerez                Mallorca         2         1  31/01/2010
# 4030     Xerez                Espanyol         1         1  28/02/2010
# 4136     Xerez                Valencia         1         3  10/01/2010
# 4145     Xerez                Tenerife         2         1  20/03/2010
# 4207     Xerez             Real Madrid         0         3  13/02/2010
# 4208     Xerez               Barcelona         0         2  02/12/2009
# 4214     Xerez                 Osasuna         1         2  24/01/2010
# 4226     Xerez                  Getafe         0         1  10/04/2010
# 4231     Xerez              Valladolid         3         0  28/03/2010
#
#      Estadio Ciudad             Arbitro
# 3881  Chapín    n/d          Pérez Lasa
# 3884  Chapín    n/d   Álvarez Izquierdo
# 3910  Chapín    n/d    Delgado Ferreiro
# 3924  Chapín    n/d   Álvarez Izquierdo
# 3928  Chapín    n/d         Mateu Lahoz
# 3930  Chapín    n/d       Pérez Burrull
# 3933  Chapín    n/d          Ayza Gámez
# 3941  Chapín    n/d          Ayza Gámez
# 3957  Chapín    n/d    González Vázquez
# 3982  Chapín    n/d       Rubinos Pérez
# 4007  Chapín    n/d    Undiano Mallenco
# 4030  Chapín    n/d     Mejuto González
# 4136  Chapín    n/d          Clos Gómez
# 4145  Chapín    n/d   Estrada Fernández
# 4207  Chapín    n/d    Turienzo Álvarez
# 4208  Chapín    n/d    Velasco Carballo
# 4214  Chapín    n/d   González González
# 4226  Chapín    n/d  Iturralde González
# 4231  Chapín    n/d       Pérez Burrull

# %%
dsFutbol['Ciudad'][dsFutbol['EquipoAnf'] == 'Xerez'] = 'Jerez de la Frontera'
dsFutbol[dsFutbol['Ciudad'] == 'Jerez de la Frontera']
# Out:
# <ipython-input-7-e4a8a6f204d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dsFutbol['Ciudad'][dsFutbol['EquipoAnf'] == 'Xerez'] = 'Jerez de la Frontera'
#      EquipoAnf               EquipoVis  ResulAnf  ResulVis       Fecha  \
# 3881     Xerez      Atlético de Madrid         0         2  05/12/2009
# 3884     Xerez                  Málaga         1         1  04/10/2009
# 3910     Xerez                Zaragoza         3         2  08/05/2010
# 3924     Xerez     Racing de Santander         2         2  18/04/2010
# 3928     Xerez       Sporting de Gijón         0         0  22/11/2009
# 3930     Xerez  Deportivo de La Coruña         0         3  23/09/2009
# 3933     Xerez                 Almería         2         1  01/05/2010
# 3941     Xerez           Athletic Club         0         1  13/09/2009
# 3957     Xerez                 Sevilla         0         2  31/10/2009
# 3982     Xerez              Villarreal         2         1  18/10/2009
# 4007     Xerez                Mallorca         2         1  31/01/2010
# 4030     Xerez                Espanyol         1         1  28/02/2010
# 4136     Xerez                Valencia         1         3  10/01/2010
# 4145     Xerez                Tenerife         2         1  20/03/2010
# 4207     Xerez             Real Madrid         0         3  13/02/2010
# 4208     Xerez               Barcelona         0         2  02/12/2009
# 4214     Xerez                 Osasuna         1         2  24/01/2010
# 4226     Xerez                  Getafe         0         1  10/04/2010
# 4231     Xerez              Valladolid         3         0  28/03/2010
#
#      Estadio                Ciudad             Arbitro
# 3881  Chapín  Jerez de la Frontera          Pérez Lasa
# 3884  Chapín  Jerez de la Frontera   Álvarez Izquierdo
# 3910  Chapín  Jerez de la Frontera    Delgado Ferreiro
# 3924  Chapín  Jerez de la Frontera   Álvarez Izquierdo
# 3928  Chapín  Jerez de la Frontera         Mateu Lahoz
# 3930  Chapín  Jerez de la Frontera       Pérez Burrull
# 3933  Chapín  Jerez de la Frontera          Ayza Gámez
# 3941  Chapín  Jerez de la Frontera          Ayza Gámez
# 3957  Chapín  Jerez de la Frontera    González Vázquez
# 3982  Chapín  Jerez de la Frontera       Rubinos Pérez
# 4007  Chapín  Jerez de la Frontera    Undiano Mallenco
# 4030  Chapín  Jerez de la Frontera     Mejuto González
# 4136  Chapín  Jerez de la Frontera          Clos Gómez
# 4145  Chapín  Jerez de la Frontera   Estrada Fernández
# 4207  Chapín  Jerez de la Frontera    Turienzo Álvarez
# 4208  Chapín  Jerez de la Frontera    Velasco Carballo
# 4214  Chapín  Jerez de la Frontera   González González
# 4226  Chapín  Jerez de la Frontera  Iturralde González
# 4231  Chapín  Jerez de la Frontera       Pérez Burrull

# %%
#Se carga el dataset de municipios
dsMunicipios = pd.read_excel('11codmun.xls', skiprows=1)
dsMunicipios
# Out:
#       CPRO  CMUN  DC            NOMBRE
# 0        1     1   4  Alegría-Dulantzi
# 1        1     2   9           Amurrio
# 2        1    49   3             Añana
# 3        1     3   5           Aramaio
# 4        1     6   6           Armiñón
# ...    ...   ...  ..               ...
# 8111    50   296   7         Zaida, La
# 8112    50   297   3          Zaragoza
# 8113    50   298   9             Zuera
# 8114    51     1   3             Ceuta
# 8115    52     1   8           Melilla
#
# [8116 rows x 4 columns]

# %%
result = pd.merge(dsFutbol, dsMunicipios, left_on="Ciudad", right_on="NOMBRE", how='left')
#result[result['NOMBRE'].isnull()]
result.head()
# Out:
#        EquipoAnf      EquipoVis  ResulAnf  ResulVis       Fecha  \
# 0          Elche  Real Sociedad         0         3  26/09/2020
# 1  Real Sociedad    Real Madrid         0         0  20/09/2020
# 2          Eibar        Osasuna         0         0  18/10/2020
# 3      Barcelona    Real Madrid         1         3  24/10/2020
# 4          Eibar  Athletic Club         1         2  27/09/2020
#
#                        Estadio         Ciudad           Arbitro  CPRO  CMUN  \
# 0      Estadio Martínez Valero          Elche      Díaz de Mera     3    65
# 1                       Anoeta  San Sebastián  Martínez Munuera    20    69
# 2  Estadio Municipal de Ipurua          Eibar     Medié Jiménez    20    30
# 3                     Camp Nou      Barcelona  Martínez Munuera     8    19
# 4  Estadio Municipal de Ipurua          Eibar      Cordero Vega    20    30
#
#    DC         NOMBRE
# 0   1          Elche
# 1   7  San Sebastián
# 2   0          Eibar
# 3   3      Barcelona
# 4   0          Eibar

# %%
dsProvincias = pd.read_csv("provinces_es.csv", sep=',')
dsProvincias.head()
# Out:
#   code  postal_code      name  phone_code iso2
# 0   VI            1     Álava         945   ES
# 1   AB            2  Albacete         967   ES
# 2    A            3   Alacant         950   ES
# 3   AL            4   Almería         920   ES
# 4   AV            5     Ávila         924   ES

# %%
result2 = pd.merge(result, dsProvincias, left_on="CPRO", right_on="postal_code", how='left')
result2
# Out:
#           EquipoAnf            EquipoVis  ResulAnf  ResulVis       Fecha  \
# 0             Elche        Real Sociedad         0         3  26/09/2020
# 1     Real Sociedad          Real Madrid         0         0  20/09/2020
# 2             Eibar              Osasuna         0         0  18/10/2020
# 3         Barcelona          Real Madrid         1         3  24/10/2020
# 4             Eibar        Athletic Club         1         2  27/09/2020
# ...             ...                  ...       ...       ...         ...
# 7668      Barcelona             Espanyol         4         2  10/12/2000
# 7669  Real Sociedad        Celta de Vigo         2         2  04/02/2001
# 7670       Numancia            Barcelona         1         1  18/03/2001
# 7671    Real Madrid  Racing de Santander         1         0  17/02/2001
# 7672    Real Madrid               Málaga         4         3  04/02/2001
#
#                             Estadio         Ciudad             Arbitro  CPRO  \
# 0           Estadio Martínez Valero          Elche        Díaz de Mera     3
# 1                            Anoeta  San Sebastián    Martínez Munuera    20
# 2       Estadio Municipal de Ipurua          Eibar       Medié Jiménez    20
# 3                          Camp Nou      Barcelona    Martínez Munuera     8
# 4       Estadio Municipal de Ipurua          Eibar        Cordero Vega    20
# ...                             ...            ...                 ...   ...
# 7668            Nou Camp (Nou Camp)      Barcelona       Daudén Ibáñez     8
# 7669                         Anoeta  San Sebastián  Andradas Asurmendi    20
# 7670  Los Pajaritos (Los Pajaritos)          Soria       Pérez Burrull    42
# 7671              Santiago Bernabéu         Madrid       Daudén Ibáñez    28
# 7672              Santiago Bernabéu         Madrid       Llonch Andreu    28
#
#       CMUN  DC         NOMBRE code  postal_code       name  phone_code iso2
# 0       65   1          Elche    A            3    Alacant         950   ES
# 1       69   7  San Sebastián   SS           20   Gipuzkoa         943   ES
# 2       30   0          Eibar   SS           20   Gipuzkoa         943   ES
# 3       19   3      Barcelona    B            8  Barcelona          93   ES
# 4       30   0          Eibar   SS           20   Gipuzkoa         943   ES
# ...    ...  ..            ...  ...          ...        ...         ...  ...
# 7668    19   3      Barcelona    B            8  Barcelona          93   ES
# 7669    69   7  San Sebastián   SS           20   Gipuzkoa         943   ES
# 7670   173   6          Soria   SO           42      Soria         975   ES
# 7671    79   6         Madrid    M           28     Madrid          91   ES
# 7672    79   6         Madrid    M           28     Madrid          91   ES
#
# [7673 rows x 17 columns]

# %%
result2.drop(['CPRO', 'CMUN', 'DC', 'NOMBRE', 'code', 'postal_code', 'phone_code', 'iso2'], axis = 'columns', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f5a791dd1ee7> in <module>
# ----> 1 result2.drop(['CPRO', 'CMUN', 'DC', 'NOMBRE', 'code', 'postal_code', 'phone_code', 'iso2'], axis = 'columns', inplace=True)
#       2 result2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['CPRO' 'CMUN' 'DC' 'NOMBRE' 'code' 'postal_code' 'phone_code' 'iso2'] not found in axis"

# %%
result2
# Out:
#           EquipoAnf            EquipoVis  ResulAnf  ResulVis       Fecha  \
# 0             Elche        Real Sociedad         0         3  26/09/2020
# 1     Real Sociedad          Real Madrid         0         0  20/09/2020
# 2             Eibar              Osasuna         0         0  18/10/2020
# 3         Barcelona          Real Madrid         1         3  24/10/2020
# 4             Eibar        Athletic Club         1         2  27/09/2020
# ...             ...                  ...       ...       ...         ...
# 7668      Barcelona             Espanyol         4         2  10/12/2000
# 7669  Real Sociedad        Celta de Vigo         2         2  04/02/2001
# 7670       Numancia            Barcelona         1         1  18/03/2001
# 7671    Real Madrid  Racing de Santander         1         0  17/02/2001
# 7672    Real Madrid               Málaga         4         3  04/02/2001
#
#                             Estadio         Ciudad             Arbitro  \
# 0           Estadio Martínez Valero          Elche        Díaz de Mera
# 1                            Anoeta  San Sebastián    Martínez Munuera
# 2       Estadio Municipal de Ipurua          Eibar       Medié Jiménez
# 3                          Camp Nou      Barcelona    Martínez Munuera
# 4       Estadio Municipal de Ipurua          Eibar        Cordero Vega
# ...                             ...            ...                 ...
# 7668            Nou Camp (Nou Camp)      Barcelona       Daudén Ibáñez
# 7669                         Anoeta  San Sebastián  Andradas Asurmendi
# 7670  Los Pajaritos (Los Pajaritos)          Soria       Pérez Burrull
# 7671              Santiago Bernabéu         Madrid       Daudén Ibáñez
# 7672              Santiago Bernabéu         Madrid       Llonch Andreu
#
#            name
# 0       Alacant
# 1      Gipuzkoa
# 2      Gipuzkoa
# 3     Barcelona
# 4      Gipuzkoa
# ...         ...
# 7668  Barcelona
# 7669   Gipuzkoa
# 7670      Soria
# 7671     Madrid
# 7672     Madrid
#
# [7673 rows x 9 columns]
